# %% [markdown]
# # Updated ELO Calculation for Final Data

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
import re

# %%
df = pd.read_json("arena_votes/arena_votes.jsonl", lines=True)
df.head(3)
# Out:
#     session_id      paper_id                  reviewer_a  \
# 0  7tppsuo8kyq  acl_2024_s59                   barebones
# 1  7tppsuo8kyq  acl_2024_s59  multi_agent_with_knowledge
# 2  7tppsuo8kyq  acl_2024_s59  multi_agent_with_knowledge
#
#                       reviewer_b technical_quality constructiveness  \
# 0     multi_agent_with_knowledge    👉  B is better   👉  B is better
# 1                     liang_etal    👈  A is better   👈  A is better
# 2  multi_agent_without_knowledge    👈  A is better   👈  A is better
#
#           clarity overall_quality  \
# 0  👉  B is better  👉  B is better
# 1  👈  A is better  👈  A is better
# 2  👈  A is better  👈  A is better
#
#                                             review_a  \
# 0  Here are my main feedback comments as a peer r...
# 1  Critical Review of "Zero-Shot Cross-Lingual Re...
# 2  Critical Review of "Zero-Shot Cross-Lingual Re...
#
#                                             review_b  \
# 0  Critical Review of "Zero-Shot Cross-Lingual Re...
# 1  Review outline:\n\n1. Significance and novelty...
# 2  Critical Review of "Zero-Shot Cross-Lingual Re...
#
#                    vote_time
# 0 2024-09-08 19:41:00.624620
# 1 2024-09-08 19:41:16.496030
# 2 2024-09-08 19:41:48.048705

# %%
df['review_a'][15]
# Out:
# 'Review outline:\n\n1. Significance and novelty\n\n2. Potential reasons for acceptance\n\n3. Potential reasons for rejection\n   a. Lack of theoretical contribution\n      - No new modeling approach or algorithm proposed\n      - Limited innovation beyond dataset cleaning and simple post-processing\n   \n   b. Insufficient experimental evaluation\n      - Only four existing models evaluated\n      - No comparison to very recent state-of-the-art approaches\n   \n   c. Questionable generalizability of the refinement solution\n      - Rule-based approach may not generalize well to other datasets/domains\n      - Relies on specific properties of Chinese characters and existing tools\n\n   d. Inadequate analysis of dataset issues and fixes\n      - No rigorous quantification of dataset quality improvements\n      - Potential for introducing new biases during manual correction process\n\n4. Suggestions for improvement'

# %%
models = ['multi_agent_with_knowledge', 'multi_agent_without_knowledge', 'liang_etal', 'barebones', 'human_reviewer']
elo_ratings = {model: 1500 for model in models}

K = 32 # Common value, adjustable

def expected_score(rating_a, rating_b):
    return 1 / (1 + 10** ((rating_b-rating_a) / 400))

def update_elo(rating_a, rating_b, outcome_a):
    expected_a = expected_score(rating_a, rating_b)
    rating_a_new = rating_a + K * (outcome_a - expected_a)
    rating_b_new = rating_b + K * ((1-outcome_a)-(1-expected_a))
    return rating_a_new, rating_b_new

for i, row in df.iterrows():
    reviewer_a = row['reviewer_a']
    reviewer_b = row['reviewer_b']
    outcome = row['overall_quality']
    rating_a = elo_ratings[reviewer_a]
    rating_b = elo_ratings[reviewer_b]
    
    if outcome == '👈  A is better':
        outcome_a = 1
    elif outcome == '👉  B is better':
        outcome_a = 0
    elif outcome == '🤝  Tie':
        outcome_a = 0.5
    elif outcome == '👎  Both are bad':
        #continue  # No change in ratings if both are bad
        outcome_a = 0.5
    new_rating_a, new_rating_b = update_elo(rating_a, rating_b, outcome_a)

    elo_ratings[reviewer_a] = new_rating_a
    elo_ratings[reviewer_b] = new_rating_b
    
for model, rating in elo_ratings.items():
    print(f"{model}: {rating:.2f}")
# Out:
# multi_agent_with_knowledge: 1675.48
# multi_agent_without_knowledge: 1629.84
# liang_etal: 1408.92
# barebones: 1463.79
# human_reviewer: 1321.97

# %%
import math
from typing import Tuple

class EloSystem:
    def __init__(self, k_factor=32):
        self.k_factor = k_factor
        self.elo_ratings = {}
        self.matches_played = {}
        self.model = LogisticRegression()

    def expected_score(self, rating_A: float, rating_B: float) -> float:
        # Standard ELO Caclulation
        return 1 / (1 + 10 ** ((rating_B - rating_A) / 400))
    
    def extract_features(self, text):
        '''
        Get feature counts:
            # of words
            # of sections
            # of lists (dashed, numbered, or lettered)
        '''
        length = len(text.split())
        sections = text.count('\n')
        
        num_lists = len(re.findall(r'\d+\.', text))
        dashed_lists = len(re.findall(r'- ', text))
        lettered_lists = len(re.findall(r'(?<!\w)[a-zA-Z]\. ', text))
        
        lists = num_lists + dashed_lists + lettered_lists
        #print(f"Lists: {lists}, Headers: {headers}, Length: {length}")
        return {
            'length': length,
            'sections': sections,
            'lists': lists,
        }
    
    def fit_bt_model(self, df):
        '''
        Fit Bradley-Terry Linear Regression Model on data
        explanation: predict p(review a is better than review b) based on feature diffs
        returns: model coefficients [length, sections, lists]
        '''
        
        # Extract features for review a and review b
        df['a_features'] = df['review_a'].apply(self.extract_features)
        df['b_features'] = df['review_b'].apply(self.extract_features)
        df['outcome'] = df['overall_quality'].apply(lambda x: 1 if '👈  A is better' in x else 0)
        
        # This represents how many MORE of each feature (length(a) - length(b))
        df['length_diff'] = df['a_features'].apply(lambda x: x['length']) - df['b_features'].apply(lambda x: x['length'])
        df['sections_diff'] = df['a_features'].apply(lambda x: x['sections']) - df['b_features'].apply(lambda x: x['sections'])
        df['lists_diff'] = df['a_features'].apply(lambda x: x['lists']) - df['b_features'].apply(lambda x: x['lists'])
        
        X = df[['length_diff', 'sections_diff', 'lists_diff']]
        y = df['outcome']
        
        # Training model
        self.model.fit(X, y)
        print(f"Model Coefficients []: {self.model.coef_}")
    
    def predict_bradley_terry(self, response_A_features, response_B_features):
        # Take actual feature difference
        feature_diff = {
            'length_diff': response_A_features['length'] - response_B_features['length'],
            'sections_diff': response_A_features['sections'] - response_B_features['sections'],
            'lists_diff': response_A_features['lists'] - response_B_features['lists'],
        }
        
        # format input for regression
        feature_diff_df = pd.DataFrame([feature_diff])
        feature_diff_df = feature_diff_df[['length_diff', 'sections_diff', 'lists_diff']]
        
        # Predicts classs probabilities [p(review b better), p(review a better)]
        # prob_a_better is the expected_outcome
        prob_A_better = self.model.predict_proba(feature_diff_df)[0][1]  
        return prob_A_better

    def update_elo(self, rating_A: float, rating_B: float, outcome_A: float, expected_A) -> Tuple[float, float]:
        '''
            Params: current Elo for A & B, Actual outcome, Expected outcome
        '''
        print(f"Current A: {rating_A}, Current B: {rating_B}, Expected Outcome A: {expected_A}, Actual Outcome A: {outcome_A}")
        new_rating_A = rating_A + self.k_factor * (outcome_A - expected_A)
        new_rating_B = rating_B + self.k_factor * ((1 - outcome_A) - (1 - expected_A))

        return new_rating_A, new_rating_B

    
    
    def process_match(self, reviewer_a, reviewer_b, outcome, review_a, review_b):
        '''
        ELO Workflow
        '''
        # Grab current ELO ratings for both reviewers, if not assigned, start w/ 1500
        rating_a = self.elo_ratings.get(reviewer_a, 1500)
        rating_b = self.elo_ratings.get(reviewer_b, 1500)
        
        # Caclculate ELO update for expected score (traditional ELO):
        expected_score_a = self.expected_score(rating_a, rating_b)
        new_rating_a_step1, new_rating_b_step1 = self.update_elo(rating_a, rating_b, outcome, expected_score_a)
        
        elo_change_a_step1 = new_rating_a_step1 - rating_a
        elo_change_b_step1 = new_rating_b_step1 - rating_b
        print(f"- Traditional ELO -- Change for A: {elo_change_a_step1}, Change for B: {elo_change_b_step1}")
        
        # Use LR model to adjust for features
        review_a_features = self.extract_features(review_a)
        review_b_features = self.extract_features(review_b)
        prob_a_better = self.predict_bradley_terry(review_a_features, review_b_features)
        new_rating_a_step2, new_rating_b_step2 = self.update_elo(new_rating_a_step1, new_rating_b_step1, outcome, prob_a_better)
        
        elo_change_a_step2 = new_rating_a_step2 - new_rating_a_step1
        elo_change_b_step2 = new_rating_b_step2 - new_rating_b_step1
        print(f"- Logistic Regression - Reviewera: {reviewer_a}, {reviewer_b}:  {prob_a_better} - Change for A: {elo_change_a_step2}, Change for B: {elo_change_b_step2}")

        
        self.elo_ratings[reviewer_a] = new_rating_a_step2
        self.elo_ratings[reviewer_b] = new_rating_b_step2

        self.matches_played[reviewer_a] = self.matches_played.get(reviewer_a, 0) + 1
        self.matches_played[reviewer_b] = self.matches_played.get(reviewer_b, 0) + 1
    
    def _calculate_confidence_interval(self, rating: float, vote_count: float) -> Tuple[float, float]:
        if vote_count == 0:
            return (rating, rating)

        # Standard deviation of the rating
        std_dev = self.k_factor / math.sqrt(vote_count)

        # 95% CI is approximately 1.96 standard deviations from the mean
        margin = 1.96 * std_dev

        lower_bound = rating - margin
        upper_bound = rating + margin

        return (lower_bound, upper_bound)
    
    def get_ratings_with_confidence_intervals(self):

        ratings_with_ci = {}
        for model, rating in self.elo_ratings.items():
            match_count = self.matches_played.get(model, 0)
            lower_bound, upper_bound = self._calculate_confidence_interval(rating, match_count)
            ratings_with_ci[model] = {
                'rating': rating,
                'confidence_interval': (lower_bound, upper_bound)
            }
        return ratings_with_ci
    
    def run_model_on_df(self, df):
        '''
        Process the whole DF
        '''
        if 'outcome' not in df.columns:
            df['outcome'] = df['overall_quality'].apply(lambda x: 1 if '👈  A is better' in x else 0)
        for idx, row in df.iterrows():
            review_a = row['review_a']
            review_b = row['review_b']
            reviewer_a = row['reviewer_a']
            reviewer_b = row['reviewer_b']

            actual_outcome = row['outcome']

            self.process_match(reviewer_a, reviewer_b, actual_outcome, review_a, review_b)

        return self.elo_ratings

# %%
'''
    Notes on outputs (print statements can be uncommented to look at this)
        - ELO changes relatively small when expected is 50/50
        - More signifficant change when elo/regression are in disagreement
'''

df = pd.read_json("arena_votes/arena_votes.jsonl", lines=True)
elo = EloSystem()
elo.fit_bt_model(df)
updated_ratings = elo.run_model_on_df(df)
print(updated_ratings)
# Out:
# Model Coefficients []: [[0.00452492 0.01901784 0.00314602]]
# Current A: 1500, Current B: 1500, Expected Outcome A: 0.5, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -16.0, Change for B: 16.0
# Current A: 1484.0, Current B: 1516.0, Expected Outcome A: 0.023929023226906224, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_with_knowledge:  0.023929023226906224 - Change for A: -0.7657287432609792, Change for B: 0.7657287432609792
# Current A: 1516.765728743261, Current B: 1500, Expected Outcome A: 0.524109112525195, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 15.228508399193743, Change for B: -15.228508399193743
# Current A: 1531.9942371424547, Current B: 1484.7714916008063, Expected Outcome A: 0.9565882488260441, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, liang_etal:  0.9565882488260441 - Change for A: 1.3891760375665854, Change for B: -1.3891760375665854
# Current A: 1533.3834131800213, Current B: 1500, Expected Outcome A: 0.547895288538814, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 14.467350766758045, Change for B: -14.467350766758045
# Current A: 1547.8507639467794, Current B: 1485.532649233242, Expected Outcome A: 0.6006859117606418, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.6006859117606418 - Change for A: 12.778050823659441, Change for B: -12.778050823659441
# Current A: 1483.234271256739, Current B: 1483.3823155632397, Expected Outcome A: 0.4997869471296125, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.006817691852348, Change for B: -16.006817691852348
# Current A: 1499.2410889485914, Current B: 1467.3754978713873, Expected Outcome A: 0.4962111371028398, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.4962111371028398 - Change for A: 16.121243612709122, Change for B: -16.121243612709122
# Current A: 1515.3623325613005, Current B: 1500, Expected Outcome A: 0.5220937771876897, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 15.29299912999386, Change for B: -15.29299912999386
# Current A: 1530.6553316912944, Current B: 1484.7070008700061, Expected Outcome A: 0.6382277154974807, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, human_reviewer:  0.6382277154974807 - Change for A: 11.576713104080682, Change for B: -11.576713104080682
# Current A: 1542.232044795375, Current B: 1560.6288147704388, Expected Outcome A: 0.4735496349920979, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -15.153588319747087, Change for B: 15.153588319747087
# Current A: 1527.078456475628, Current B: 1575.7824030901859, Expected Outcome A: 0.03438180982482994, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_with_knowledge:  0.03438180982482994 - Change for A: -1.100217914394534, Change for B: 1.100217914394534
# Current A: 1472.7545984095825, Current B: 1473.1302877659255, Expected Outcome A: 0.49945933976602835, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.017301127487144, Change for B: -16.017301127487144
# Current A: 1488.7718995370697, Current B: 1457.1129866384383, Expected Outcome A: 0.872384133992251, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, human_reviewer:  0.872384133992251 - Change for A: 4.083707712248042, Change for B: -4.083707712248042
# Current A: 1525.9782385612334, Current B: 1492.8556072493177, Expected Outcome A: 0.5475234102419246, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -17.52074912774151, Change for B: 17.52074912774151
# Current A: 1508.457489433492, Current B: 1510.3763563770592, Expected Outcome A: 0.07698376610891328, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_without_knowledge:  0.07698376610891328 - Change for A: -2.4634805154851165, Change for B: 2.4634805154851165
# Current A: 1451.2542542586782, Current B: 1453.0292789261903, Expected Outcome A: 0.4974455563876842, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.081742195594188, Change for B: -16.081742195594188
# Current A: 1467.3359964542724, Current B: 1436.947536730596, Expected Outcome A: 0.3828407925093363, Actual Outcome A: 1
# - Logistic Regression - Reviewera: liang_etal, human_reviewer:  0.3828407925093363 - Change for A: 19.749094639701298, Change for B: -19.749094639701298
# Current A: 1512.8398368925443, Current B: 1505.9940089180068, Expected Outcome A: 0.5098506636188213, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 15.684778764197745, Change for B: -15.684778764197745
# Current A: 1528.524615656742, Current B: 1490.309230153809, Expected Outcome A: 0.7829197410208087, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, barebones:  0.7829197410208087 - Change for A: 6.94656828733423, Change for B: -6.94656828733423
# Current A: 1487.0850910939737, Current B: 1483.3626618664748, Expected Outcome A: 0.5053568013129807, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -16.171417642015285, Change for B: 16.171417642015285
# Current A: 1470.9136734519584, Current B: 1499.53407950849, Expected Outcome A: 0.24657748322843906, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.24657748322843906 - Change for A: -7.890479463310157, Change for B: 7.890479463310157
# Current A: 1507.4245589718003, Current B: 1463.0231939886482, Expected Outcome A: 0.5635530900819612, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 13.96630111737727, Change for B: -13.96630111737727
# Current A: 1521.3908600891775, Current B: 1449.056892871271, Expected Outcome A: 0.4789276638524692, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.4789276638524692 - Change for A: 16.67431475672106, Change for B: -16.67431475672106
# Current A: 1417.1984420908948, Current B: 1432.38257811455, Expected Outcome A: 0.47816217330262306, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.698810454316117, Change for B: -16.698810454316117
# Current A: 1433.897252545211, Current B: 1415.6837676602338, Expected Outcome A: 0.32656083744817493, Actual Outcome A: 1
# - Logistic Regression - Reviewera: human_reviewer, liang_etal:  0.32656083744817493 - Change for A: 21.55005320165833, Change for B: -21.55005320165833
# Current A: 1576.8826210045804, Current B: 1535.4711839440763, Expected Outcome A: 0.5593152237906539, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 14.101912838699036, Change for B: -14.101912838699036
# Current A: 1590.9845338432795, Current B: 1521.3692711053773, Expected Outcome A: 0.5623103961958781, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.5623103961958781 - Change for A: 14.006067321731962, Change for B: -14.006067321731962
# Current A: 1538.0651748458986, Current B: 1507.3632037836453, Expected Outcome A: 0.544069039059516, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -17.410209249904483, Change for B: 17.410209249904483
# Current A: 1520.654965595994, Current B: 1524.7734130335498, Expected Outcome A: 0.0692712224123211, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_without_knowledge:  0.0692712224123211 - Change for A: -2.2166791171941895, Change for B: 2.2166791171941895
# Current A: 1394.1337144585755, Current B: 1518.4382864788, Expected Outcome A: 0.3283726323960469, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -10.507924236673489, Change for B: 10.507924236673489
# Current A: 1383.625790221902, Current B: 1528.9462107154734, Expected Outcome A: 0.16374374477417186, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.16374374477417186 - Change for A: -5.239799832773542, Change for B: 5.239799832773542
# Current A: 1526.990092150744, Current B: 1534.186010548247, Expected Outcome A: 0.4896457214852138, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.33133691247326, Change for B: -16.33133691247326
# Current A: 1543.3214290632172, Current B: 1517.8546736357737, Expected Outcome A: 0.8016516201910803, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, barebones:  0.8016516201910803 - Change for A: 6.347148153885428, Change for B: -6.347148153885428
# Current A: 1604.9906011650114, Current B: 1549.6685772171027, Expected Outcome A: 0.5789486940327996, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 13.473641790950524, Change for B: -13.473641790950524
# Current A: 1618.464242955962, Current B: 1536.1949354261521, Expected Outcome A: 0.44648483654694765, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.44648483654694765 - Change for A: 17.712485230497578, Change for B: -17.712485230497578
# Current A: 1518.4824501956546, Current B: 1511.5075254818883, Expected Outcome A: 0.5100363752817783, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 15.678835990983089, Change for B: -15.678835990983089
# Current A: 1534.1612861866377, Current B: 1495.8286894909052, Expected Outcome A: 0.7195483705431067, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, barebones:  0.7195483705431067 - Change for A: 8.974452142620521, Change for B: -8.974452142620521
# Current A: 1636.1767281864595, Current B: 1543.1357383292582, Expected Outcome A: 0.6307852434727202, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 11.814872208872885, Change for B: -11.814872208872885
# Current A: 1647.9916003953324, Current B: 1531.3208661203853, Expected Outcome A: 0.7434359764375364, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.7434359764375364 - Change for A: 8.210048753998763, Change for B: -8.210048753998763
# Current A: 1486.8542373482846, Current B: 1378.3859903891284, Expected Outcome A: 0.651217103026494, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -20.83894729684789, Change for B: 20.83894729684789
# Current A: 1466.0152900514368, Current B: 1399.2249376859763, Expected Outcome A: 0.40816620912786955, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.40816620912786955 - Change for A: -13.061318692091845, Change for B: 13.061318692091845
# Current A: 1412.2862563780682, Current B: 1452.953971359345, Expected Outcome A: 0.4417402821838087, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -14.13568902988186, Change for B: 14.13568902988186
# Current A: 1398.1505673481863, Current B: 1467.0896603892268, Expected Outcome A: 0.14700664715215594, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.14700664715215594 - Change for A: -4.7042127088689085, Change for B: 4.7042127088689085
# Current A: 1656.2016491493312, Current B: 1523.1108173663865, Expected Outcome A: 0.6826836638350678, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 10.154122757277719, Change for B: -10.154122757277719
# Current A: 1666.3557719066089, Current B: 1512.9566946091088, Expected Outcome A: 0.8074681030870808, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.8074681030870808 - Change for A: 6.161020701213374, Change for B: -6.161020701213374
# Current A: 1393.4463546393174, Current B: 1455.4473057468692, Expected Outcome A: 0.41170870206207955, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -13.174678465986517, Change for B: 13.174678465986517
# Current A: 1380.271676173331, Current B: 1468.6219842128558, Expected Outcome A: 0.36844846225247235, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, human_reviewer:  0.36844846225247235 - Change for A: -11.790350792079153, Change for B: 11.790350792079153
# Current A: 1368.4813253812517, Current B: 1471.7938730980957, Expected Outcome A: 0.35555378594552867, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -11.377721150257003, Change for B: 11.377721150257003
# Current A: 1357.1036042309947, Current B: 1483.1715942483527, Expected Outcome A: 0.24770295064648926, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.24770295064648926 - Change for A: -7.926494420687732, Change for B: 7.926494420687732
# Current A: 1480.412335004935, Current B: 1491.0980886690404, Expected Outcome A: 0.48462681136083413, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.491942036453338, Change for B: -16.491942036453338
# Current A: 1496.9042770413882, Current B: 1474.606146632587, Expected Outcome A: 0.23637326676120157, Actual Outcome A: 1
# - Logistic Regression - Reviewera: human_reviewer, barebones:  0.23637326676120157 - Change for A: 24.43605546364165, Change for B: -24.43605546364165
# Current A: 1506.7956739078954, Current B: 1521.34033250503, Expected Outcome A: 0.479080772607431, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.669415276562177, Change for B: -16.669415276562177
# Current A: 1523.4650891844576, Current B: 1504.6709172284677, Expected Outcome A: 0.885165757553683, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, human_reviewer:  0.885165757553683 - Change for A: 3.6746957582820414, Change for B: -3.6746957582820414
# Current A: 1450.1700911689454, Current B: 1500.9962214701857, Expected Outcome A: 0.42737267005031326, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -13.675925441609934, Change for B: 13.675925441609934
# Current A: 1436.4941657273355, Current B: 1514.6721469117956, Expected Outcome A: 0.49284491355145266, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, human_reviewer:  0.49284491355145266 - Change for A: -15.771037233646439, Change for B: 15.771037233646439
# Current A: 1672.5167926078223, Current B: 1527.1397849427397, Expected Outcome A: 0.6978029201638488, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 9.670306554756735, Change for B: -9.670306554756735
# Current A: 1682.187099162579, Current B: 1517.469478387983, Expected Outcome A: 0.5289636462090754, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.5289636462090754 - Change for A: 15.073163321309494, Change for B: -15.073163321309494
# Current A: 1530.443184145442, Current B: 1502.3963150666734, Expected Outcome A: 0.5402752414364094, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -17.28880772596517, Change for B: 17.28880772596517
# Current A: 1513.1543764194769, Current B: 1519.6851227926386, Expected Outcome A: 0.03755846949317606, Actual Outcome A: 0
# - Logistic Regression - Reviewera: human_reviewer, multi_agent_without_knowledge:  0.03755846949317606 - Change for A: -1.2018710237816776, Change for B: 1.2018710237816776
# Current A: 1520.8869938164203, Current B: 1511.9525053956952, Expected Outcome A: 0.512854928927504, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 15.58864227431991, Change for B: -15.58864227431991
# Current A: 1536.4756360907402, Current B: 1496.3638631213753, Expected Outcome A: 0.9193121122703063, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, human_reviewer:  0.9193121122703063 - Change for A: 2.5820124073502484, Change for B: -2.5820124073502484
# Current A: 1420.723128493689, Current B: 1493.781850714025, Expected Outcome A: 0.3963827998650695, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -12.684249595682331, Change for B: 12.684249595682331
# Current A: 1408.0388788980067, Current B: 1506.4661003097074, Expected Outcome A: 0.45629859963489433, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, human_reviewer:  0.45629859963489433 - Change for A: -14.601555188316524, Change for B: 14.601555188316524
# Current A: 1349.177109810307, Current B: 1393.4373237096902, Expected Outcome A: 0.436646771157321, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -13.972696677034264, Change for B: 13.972696677034264
# Current A: 1335.2044131332727, Current B: 1407.4100203867245, Expected Outcome A: 0.24709017790732735, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.24709017790732735 - Change for A: -7.906885693034383, Change for B: 7.906885693034383
# Current A: 1521.067655498024, Current B: 1415.3169060797588, Expected Outcome A: 0.6476556640626512, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 11.27501874999507, Change for B: -11.27501874999507
# Current A: 1532.342674248019, Current B: 1404.0418873297638, Expected Outcome A: 0.26385324705563046, Actual Outcome A: 1
# - Logistic Regression - Reviewera: human_reviewer, barebones:  0.26385324705563046 - Change for A: 23.556696094219888, Change for B: -23.556696094219888
# Current A: 1539.0576484980904, Current B: 1697.2602624838885, Expected Outcome A: 0.28685918398988447, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -9.179493887676244, Change for B: 9.179493887676244
# Current A: 1529.8781546104142, Current B: 1706.4397563715647, Expected Outcome A: 0.14806245981778218, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.14806245981778218 - Change for A: -4.737998714168953, Change for B: 4.737998714168953
# Current A: 1711.1777550857337, Current B: 1525.1401558962452, Expected Outcome A: 0.7447715511337356, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 8.16731036372039, Change for B: -8.16731036372039
# Current A: 1719.345065449454, Current B: 1516.9728455325248, Expected Outcome A: 0.6338083515103816, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.6338083515103816 - Change for A: 11.718132751667781, Change for B: -11.718132751667781
# Current A: 1327.2975274402384, Current B: 1380.4851912355439, Expected Outcome A: 0.42404918771013533, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 18.430425993275776, Change for B: -18.430425993275776
# Current A: 1345.7279534335141, Current B: 1362.054765242268, Expected Outcome A: 0.1908583784583968, Actual Outcome A: 1
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.1908583784583968 - Change for A: 25.892531889331394, Change for B: -25.892531889331394
# Current A: 1336.1622333529367, Current B: 1371.6204853228455, Expected Outcome A: 0.4491479034338437, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 17.627267090116902, Change for B: -17.627267090116902
# Current A: 1353.7895004430536, Current B: 1353.9932182327286, Expected Outcome A: 0.5604905279398475, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.5604905279398475 - Change for A: 14.064303105924864, Change for B: -14.064303105924864
# Current A: 1505.254712780857, Current B: 1367.8538035489785, Expected Outcome A: 0.6880338209013116, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -22.017082268841932, Change for B: 22.017082268841932
# Current A: 1483.2376305120151, Current B: 1389.8708858178204, Expected Outcome A: 0.7981511390282277, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, barebones:  0.7981511390282277 - Change for A: -25.540836448903292, Change for B: 25.540836448903292
# Current A: 1415.4117222667237, Current B: 1339.9289151268038, Expected Outcome A: 0.6069510451717685, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -19.42243344549661, Change for B: 19.42243344549661
# Current A: 1395.989288821227, Current B: 1359.3513485723004, Expected Outcome A: 0.4550874405983699, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.4550874405983699 - Change for A: -14.562798099147813, Change for B: 14.562798099147813
# Current A: 1457.6967940631118, Current B: 1381.4264907220793, Expected Outcome A: 0.6080319643514835, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 12.542977140752555, Change for B: -12.542977140752555
# Current A: 1470.2397712038644, Current B: 1368.8835135813267, Expected Outcome A: 0.7945568050961098, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, barebones:  0.7945568050961098 - Change for A: 6.574182236924571, Change for B: -6.574182236924571
# Current A: 1731.0631982011218, Current B: 1476.813953440789, Expected Outcome A: 0.8120790515666468, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -25.986529650132752, Change for B: 25.986529650132752
# Current A: 1705.076668550989, Current B: 1502.8004830909217, Expected Outcome A: 0.5369443231004828, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.5369443231004828 - Change for A: -17.182218339215524, Change for B: 17.182218339215524
# Current A: 1519.9827014301372, Current B: 1687.8944502117736, Expected Outcome A: 0.2755631596352316, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -8.818021108327457, Change for B: 8.818021108327457
# Current A: 1511.1646803218098, Current B: 1696.712471320101, Expected Outcome A: 0.2059788974499461, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.2059788974499461 - Change for A: -6.591324718398255, Change for B: 6.591324718398255
# Current A: 1362.3093313444022, Current B: 1373.9141466714482, Expected Outcome A: 0.4833055361928461, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.534222841828978, Change for B: -16.534222841828978
# Current A: 1378.8435541862311, Current B: 1357.3799238296192, Expected Outcome A: 0.4962111371028398, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.4962111371028398 - Change for A: 16.121243612709122, Change for B: -16.121243612709122
# Current A: 1341.25868021691, Current B: 1394.9647977989403, Expected Outcome A: 0.4233204543933427, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -13.546254540586915, Change for B: 13.546254540586915
# Current A: 1327.7124256763232, Current B: 1408.5110523395272, Expected Outcome A: 0.23395117568905302, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.23395117568905302 - Change for A: -7.486437622049607, Change for B: 7.486437622049607
# Current A: 1504.5733556034115, Current B: 1703.3037960384993, Expected Outcome A: 0.2415895763596072, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -7.730866443507466, Change for B: 7.730866443507466
# Current A: 1496.842489159904, Current B: 1711.0346624820068, Expected Outcome A: 0.1666423366517327, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.1666423366517327 - Change for A: -5.332554772855474, Change for B: 5.332554772855474
# Current A: 1716.3672172548622, Current B: 1491.5099343870486, Expected Outcome A: 0.7848880606528943, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -25.11641794089269, Change for B: 25.11641794089269
# Current A: 1691.2507993139695, Current B: 1516.6263523279413, Expected Outcome A: 0.6006859117606418, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.6006859117606418 - Change for A: -19.22194917634056, Change for B: 19.22194917634056
# Current A: 1535.8483015042818, Current B: 1672.028850137629, Expected Outcome A: 0.3134760278314197, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -10.031232890605452, Change for B: 10.031232890605452
# Current A: 1525.8170686136764, Current B: 1682.0600830282344, Expected Outcome A: 0.05831298376821392, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.05831298376821392 - Change for A: -1.866015480582746, Change for B: 1.866015480582746
# Current A: 1320.2259880542736, Current B: 1415.9974899615768, Expected Outcome A: 0.3655616731307011, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -11.697973540182375, Change for B: 11.697973540182375
# Current A: 1308.5280145140912, Current B: 1427.6954635017591, Expected Outcome A: 0.1812570952606075, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.1812570952606075 - Change for A: -5.800227048339366, Change for B: 5.800227048339366
# Current A: 1433.4956905500985, Current B: 1302.7277874657518, Expected Outcome A: 0.6797799137713433, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 10.247042759317083, Change for B: -10.247042759317083
# Current A: 1443.7427333094156, Current B: 1292.4807447064347, Expected Outcome A: 0.5760464678845674, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.5760464678845674 - Change for A: 13.566513027693873, Change for B: -13.566513027693873
# Current A: 1683.9260985088172, Current B: 1523.9510531330936, Expected Outcome A: 0.7152234934130353, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -22.887151789217114, Change for B: 22.887151789217114
# Current A: 1661.0389467196, Current B: 1546.8382049223108, Expected Outcome A: 0.8292836691917634, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.8292836691917634 - Change for A: -26.53707741413632, Change for B: 26.53707741413632
# Current A: 1457.3092463371095, Current B: 1573.375282336447, Expected Outcome A: 0.3389157338613722, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -10.845303483563839, Change for B: 10.845303483563839
# Current A: 1446.4639428535456, Current B: 1584.220585820011, Expected Outcome A: 0.06617727615940351, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_without_knowledge:  0.06617727615940351 - Change for A: -2.1176728371008267, Change for B: 2.1176728371008267
# Current A: 1634.5018693054637, Current B: 1586.3382586571117, Expected Outcome A: 0.5688723940719639, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -18.20391661030294, Change for B: 18.20391661030294
# Current A: 1616.2979526951608, Current B: 1604.5421752674147, Expected Outcome A: 0.7879954603279793, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.7879954603279793 - Change for A: -25.215854730495266, Change for B: 25.215854730495266
# Current A: 1629.75802999791, Current B: 1591.0820979646655, Expected Outcome A: 0.5554303693357567, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -17.773771818744308, Change for B: 17.773771818744308
# Current A: 1611.9842581791656, Current B: 1608.8558697834098, Expected Outcome A: 0.07487049490125805, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.07487049490125805 - Change for A: -2.3958558368401555, Change for B: 2.3958558368401555
# Current A: 1278.9142316787409, Current B: 1444.3462700164448, Expected Outcome A: 0.2784218329896336, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -8.909498655668358, Change for B: 8.909498655668358
# Current A: 1270.0047330230725, Current B: 1453.2557686721132, Expected Outcome A: 0.2623137442191405, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.2623137442191405 - Change for A: -8.394039815012547, Change for B: 8.394039815012547
# Current A: 1461.6498084871257, Current B: 1609.5884023423255, Expected Outcome A: 0.2990966993769605, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -9.571094380062732, Change for B: 9.571094380062732
# Current A: 1452.078714107063, Current B: 1619.1594967223882, Expected Outcome A: 0.1274631374112442, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_without_knowledge:  0.1274631374112442 - Change for A: -4.078820397159916, Change for B: 4.078820397159916
# Current A: 1261.61069320806, Current B: 1447.999893709903, Expected Outcome A: 0.2548439074734154, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -8.155005039149273, Change for B: 8.155005039149273
# Current A: 1253.4556881689107, Current B: 1456.1548987490523, Expected Outcome A: 0.16374374477417186, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.16374374477417186 - Change for A: -5.239799832773542, Change for B: 5.239799832773542
# Current A: 1611.25172562025, Current B: 1623.2383171195481, Expected Outcome A: 0.4827567489760575, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -15.448215967233864, Change for B: 15.448215967233864
# Current A: 1595.8035096530161, Current B: 1638.686533086782, Expected Outcome A: 0.44648483654694765, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.44648483654694765 - Change for A: -14.287514769502422, Change for B: 14.287514769502422
# Current A: 1652.9740478562844, Current B: 1581.5159948835137, Expected Outcome A: 0.6014104890795025, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -19.24513565054417, Change for B: 19.24513565054417
# Current A: 1633.7289122057402, Current B: 1600.7611305340579, Expected Outcome A: 0.27162264351263066, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.27162264351263066 - Change for A: -8.69192459240412, Change for B: 8.69192459240412
# Current A: 1461.3946985818259, Current B: 1625.0369876133361, Expected Outcome A: 0.280496379992817, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -8.975884159770203, Change for B: 8.975884159770203
# Current A: 1452.4188144220557, Current B: 1634.0128717731063, Expected Outcome A: 0.0692712224123211, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_without_knowledge:  0.0692712224123211 - Change for A: -2.2166791171941895, Change for B: 2.2166791171941895
# Current A: 1248.2158883361371, Current B: 1450.2021353048615, Expected Outcome A: 0.23817225466690975, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 24.378487850658985, Change for B: -24.378487850658985
# Current A: 1272.5943761867961, Current B: 1425.8236474542025, Expected Outcome A: 0.30370050623349965, Actual Outcome A: 1
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.30370050623349965 - Change for A: 22.281583800528097, Change for B: -22.281583800528097
# Current A: 1403.5420636536744, Current B: 1294.8759599873242, Expected Outcome A: 0.651475753104814, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -20.84722409935398, Change for B: 20.84722409935398
# Current A: 1382.6948395543204, Current B: 1315.7231840866782, Expected Outcome A: 0.40816620912786955, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.40816620912786955 - Change for A: -13.061318692091845, Change for B: 13.061318692091845
# Current A: 1609.453055126462, Current B: 1636.2295508903005, Expected Outcome A: 0.4615416375989541, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -14.769332403166572, Change for B: 14.769332403166572
# Current A: 1594.6837227232954, Current B: 1650.998883293467, Expected Outcome A: 0.7434359764375364, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.7434359764375364 - Change for A: -23.789951246001237, Change for B: 23.789951246001237
# Current A: 1674.7888345394683, Current B: 1570.8937714772942, Expected Outcome A: 0.6452141842061214, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -20.64685389459578, Change for B: 20.64685389459578
# Current A: 1654.1419806448725, Current B: 1591.54062537189, Expected Outcome A: 0.09404692773489783, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.09404692773489783 - Change for A: -3.0095016875168312, Change for B: 3.0095016875168312
# Current A: 1594.5501270594068, Current B: 1651.1324789573557, Expected Outcome A: 0.41928378824661905, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 18.582918776108272, Change for B: -18.582918776108272
# Current A: 1613.133045835515, Current B: 1632.5495601812474, Expected Outcome A: 0.8074681030870808, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.8074681030870808 - Change for A: 6.161020701213374, Change for B: -6.161020701213374
# Current A: 1369.6335208622286, Current B: 1328.78450277877, Expected Outcome A: 0.5585170758815735, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 14.127453571789601, Change for B: -14.127453571789601
# Current A: 1383.7609744340182, Current B: 1314.6570492069804, Expected Outcome A: 0.6357545816532097, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.6357545816532097 - Change for A: 11.655853387097295, Change for B: -11.655853387097295
# Current A: 1303.0011958198832, Current B: 1395.4168278211155, Expected Outcome A: 0.37005353819582404, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -11.841713222266435, Change for B: 11.841713222266435
# Current A: 1291.1594825976167, Current B: 1407.258541043382, Expected Outcome A: 0.14700664715215594, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.14700664715215594 - Change for A: -4.7042127088689085, Change for B: 4.7042127088689085
# Current A: 1626.388539480034, Current B: 1619.2940665367285, Expected Outcome A: 0.5102083485001747, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -16.326667152005484, Change for B: 16.326667152005484
# Current A: 1610.0618723280286, Current B: 1635.620733688734, Expected Outcome A: 0.06692388052597159, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.06692388052597159 - Change for A: -2.141564176831025, Change for B: 2.141564176831025
# Current A: 1637.762297865565, Current B: 1607.9203081511976, Expected Outcome A: 0.5428407751350457, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 14.629095195678474, Change for B: -14.629095195678474
# Current A: 1652.3913930612434, Current B: 1593.291212955519, Expected Outcome A: 0.5620328079129076, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.5620328079129076 - Change for A: 14.014950146786987, Change for B: -14.014950146786987
# Current A: 1286.4552698887478, Current B: 1411.9627537522508, Expected Outcome A: 0.3268472902196377, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -10.459113287028458, Change for B: 10.459113287028458
# Current A: 1275.9961566017193, Current B: 1422.4218670392793, Expected Outcome A: 0.2556035351597083, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.2556035351597083 - Change for A: -8.179313125110639, Change for B: 8.179313125110639
# Current A: 1579.276262808732, Current B: 1555.8993703422389, Expected Outcome A: 0.5335913767875006, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 14.92507594280005, Change for B: -14.92507594280005
# Current A: 1594.2013387515321, Current B: 1540.9742943994388, Expected Outcome A: 0.9008812053211707, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, human_reviewer:  0.9008812053211707 - Change for A: 3.1718014297225636, Change for B: -3.1718014297225636
# Current A: 1666.4063432080304, Current B: 1597.3731401812547, Expected Outcome A: 0.598059711757708, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -19.1379107762466, Change for B: 19.1379107762466
# Current A: 1647.2684324317838, Current B: 1616.5110509575013, Expected Outcome A: 0.6006859117606418, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.6006859117606418 - Change for A: -19.22194917634056, Change for B: 19.22194917634056
# Current A: 1430.60118016439, Current B: 1537.8024929697162, Expected Outcome A: 0.3504412157281323, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 20.785881096699768, Change for B: -20.785881096699768
# Current A: 1451.3870612610897, Current B: 1517.0166118730165, Expected Outcome A: 0.5779660984257122, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, human_reviewer:  0.5779660984257122 - Change for A: 13.505084850377216, Change for B: -13.505084850377216
# Current A: 1503.5115270226393, Current B: 1464.892146111467, Expected Outcome A: 0.5553499844922302, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -17.771199503751404, Change for B: 17.771199503751404
# Current A: 1485.7403275188879, Current B: 1482.6633456152183, Expected Outcome A: 0.18009281714277373, Actual Outcome A: 0
# - Logistic Regression - Reviewera: human_reviewer, barebones:  0.18009281714277373 - Change for A: -5.762970148568684, Change for B: 5.762970148568684
# Current A: 1267.8168434766087, Current B: 1479.9773573703192, Expected Outcome A: 0.22770879468463023, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 24.713318570091815, Change for B: -24.713318570091815
# Current A: 1292.5301620467005, Current B: 1455.2640388002274, Expected Outcome A: 0.4616077070429915, Actual Outcome A: 1
# - Logistic Regression - Reviewera: liang_etal, human_reviewer:  0.4616077070429915 - Change for A: 17.228553374624198, Change for B: -17.228553374624198
# Current A: 1488.426315763787, Current B: 1309.7587154213247, Expected Outcome A: 0.7366237024373653, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 8.428041522004378, Change for B: -8.428041522004378
# Current A: 1496.8543572857914, Current B: 1301.3306738993203, Expected Outcome A: 0.4962111371028398, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.4962111371028398 - Change for A: 16.121243612709122, Change for B: -16.121243612709122
# Current A: 1635.7330001338419, Current B: 1628.0464832554433, Expected Outcome A: 0.5110599826016844, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -16.35391944325397, Change for B: 16.35391944325397
# Current A: 1619.379080690588, Current B: 1644.4004026986972, Expected Outcome A: 0.1666423366517327, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.1666423366517327 - Change for A: -5.332554772855474, Change for B: 5.332554772855474
# Current A: 1285.2094302866112, Current B: 1512.9756008985005, Expected Outcome A: 0.21229823827627867, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -6.793543624840822, Change for B: 6.793543624840822
# Current A: 1278.4158866617704, Current B: 1519.7691445233413, Expected Outcome A: 0.23395117568905302, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.23395117568905302 - Change for A: -7.486437622049607, Change for B: 7.486437622049607
# Current A: 1527.255582145391, Current B: 1270.9294490397208, Expected Outcome A: 0.813896741609267, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 5.955304268503369, Change for B: -5.955304268503369
# Current A: 1533.2108864138943, Current B: 1264.9741447712174, Expected Outcome A: 0.5760464678845674, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.5760464678845674 - Change for A: 13.566513027693873, Change for B: -13.566513027693873
# Current A: 1614.0465259177324, Current B: 1649.7329574715527, Expected Outcome A: 0.4488229450136344, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -14.362334240436212, Change for B: 14.362334240436212
# Current A: 1599.6841916772962, Current B: 1664.095291711989, Expected Outcome A: 0.05831298376821392, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.05831298376821392 - Change for A: -1.866015480582746, Change for B: 1.866015480582746
# Current A: 1251.4076317435236, Current B: 1546.7773994415882, Expected Outcome A: 0.15442803826892437, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -4.941697224605605, Change for B: 4.941697224605605
# Current A: 1246.465934518918, Current B: 1551.7190966661938, Expected Outcome A: 0.1812570952606075, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.1812570952606075 - Change for A: -5.800227048339366, Change for B: 5.800227048339366
# Current A: 1597.8181761967135, Current B: 1665.9613071925717, Expected Outcome A: 0.40317255361060783, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -12.901521715539502, Change for B: 12.901521715539502
# Current A: 1584.916654481174, Current B: 1678.8628289081112, Expected Outcome A: 0.2482484277302998, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.2482484277302998 - Change for A: -7.943949687369695, Change for B: 7.943949687369695
# Current A: 1686.8067785954809, Current B: 1576.9727047938043, Expected Outcome A: 0.6530007711492257, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 11.103975323224859, Change for B: -11.103975323224859
# Current A: 1697.9107539187057, Current B: 1565.8687294705794, Expected Outcome A: 0.47668859707918737, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.47668859707918737 - Change for A: 16.745964893465953, Change for B: -16.745964893465953
# Current A: 1549.1227645771135, Current B: 1557.5193237145331, Expected Outcome A: 0.48791873201311187, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -15.61339942441964, Change for B: 15.61339942441964
# Current A: 1533.5093651526938, Current B: 1573.1327231389528, Expected Outcome A: 0.8926789533167452, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, barebones:  0.8926789533167452 - Change for A: -28.56572650613589, Change for B: 28.56572650613589
# Current A: 1240.6657074705786, Current B: 1438.0354854256032, Expected Outcome A: 0.2430276008478446, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -7.776883227131066, Change for B: 7.776883227131066
# Current A: 1232.8888242434475, Current B: 1445.8123686527342, Expected Outcome A: 0.5467767721628066, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, human_reviewer:  0.5467767721628066 - Change for A: -17.49685670920985, Change for B: 17.49685670920985
# Current A: 1504.943638646558, Current B: 1601.6984496450887, Expected Outcome A: 0.36424988317780854, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -11.65599626168978, Change for B: 11.65599626168978
# Current A: 1493.2876423848681, Current B: 1613.3544459067784, Expected Outcome A: 0.8254724887326986, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, barebones:  0.8254724887326986 - Change for A: -26.415119639446402, Change for B: 26.415119639446402
# Current A: 1215.3919675342377, Current B: 1463.309225361944, Expected Outcome A: 0.19354681065238974, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -6.1934979408765685, Change for B: 6.1934979408765685
# Current A: 1209.198469593361, Current B: 1469.5027233028206, Expected Outcome A: 0.3636260595661677, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, human_reviewer:  0.3636260595661677 - Change for A: -11.63603390611729, Change for B: 11.63603390611729
# Current A: 1481.138757208938, Current B: 1639.7695655462248, Expected Outcome A: 0.28635520508371964, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 22.83663343732087, Change for B: -22.83663343732087
# Current A: 1503.9753906462588, Current B: 1616.932932108904, Expected Outcome A: 0.24194252341664213, Actual Outcome A: 1
# - Logistic Regression - Reviewera: human_reviewer, barebones:  0.24194252341664213 - Change for A: 24.25783925066753, Change for B: -24.25783925066753
# Current A: 1714.6567188121717, Current B: 1466.8725227454217, Expected Outcome A: 0.8063336045202827, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 6.19732465535094, Change for B: -6.19732465535094
# Current A: 1720.8540434675226, Current B: 1460.6751980900708, Expected Outcome A: 0.5289636462090754, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.5289636462090754 - Change for A: 15.073163321309494, Change for B: -15.073163321309494
# Current A: 1528.2332298969263, Current B: 1197.5624356872438, Expected Outcome A: 0.870286478332914, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 4.150832693346729, Change for B: -4.150832693346729
# Current A: 1532.384062590273, Current B: 1193.411602993897, Expected Outcome A: 0.34019833431449964, Actual Outcome A: 1
# - Logistic Regression - Reviewera: human_reviewer, liang_etal:  0.34019833431449964 - Change for A: 21.113653301935983, Change for B: -21.113653301935983
# Current A: 1735.927206788832, Current B: 1445.6020347687613, Expected Outcome A: 0.8417418790055953, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 5.064259871820923, Change for B: -5.064259871820923
# Current A: 1740.991466660653, Current B: 1440.5377748969404, Expected Outcome A: 0.6157804048319918, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.6157804048319918 - Change for A: 12.295027045376173, Change for B: -12.295027045376173
# Current A: 1553.497715892209, Current B: 1592.6750928582364, Expected Outcome A: 0.4438569769150638, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -14.203423261282069, Change for B: 14.203423261282069
# Current A: 1539.294292630927, Current B: 1606.8785161195185, Expected Outcome A: 0.23637326676120157, Actual Outcome A: 0
# - Logistic Regression - Reviewera: human_reviewer, barebones:  0.23637326676120157 - Change for A: -7.563944536358349, Change for B: 7.563944536358349
# Current A: 1428.2427478515642, Current B: 1614.4424606558769, Expected Outcome A: 0.2550511001189723, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 23.83836479619299, Change for B: -23.83836479619299
# Current A: 1452.0811126477572, Current B: 1590.6040958596839, Expected Outcome A: 0.8130973425888525, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, barebones:  0.8130973425888525 - Change for A: 5.980885037156668, Change for B: -5.980885037156668
# Current A: 1584.6232108225272, Current B: 1458.0619976849139, Expected Outcome A: 0.6744858812131135, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -21.5835481988197, Change for B: 21.5835481988197
# Current A: 1563.0396626237075, Current B: 1479.6455458837336, Expected Outcome A: 0.06467301746737351, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_without_knowledge:  0.06467301746737351 - Change for A: -2.0695365589558605, Change for B: 2.0695365589558605
# Current A: 1560.9701260647516, Current B: 1481.7150824426894, Expected Outcome A: 0.6121191397193041, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -19.58781247101774, Change for B: 19.58781247101774
# Current A: 1541.382313593734, Current B: 1501.3028949137072, Expected Outcome A: 0.059795738507287095, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_without_knowledge:  0.059795738507287095 - Change for A: -1.913463632233288, Change for B: 1.913463632233288
# Current A: 1539.4688499615006, Current B: 1531.7303480945686, Expected Outcome A: 0.511134758160748, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -16.356312261144012, Change for B: 16.356312261144012
# Current A: 1523.1125377003566, Current B: 1548.0866603557126, Expected Outcome A: 0.48519678048024006, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, human_reviewer:  0.48519678048024006 - Change for A: -15.526296975367586, Change for B: 15.526296975367586
# Current A: 1172.297949691961, Current B: 1563.6129573310802, Expected Outcome A: 0.09512626862448227, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 28.95595940401654, Change for B: -28.95595940401654
# Current A: 1201.2539090959776, Current B: 1534.6569979270637, Expected Outcome A: 0.35937626903546926, Actual Outcome A: 1
# ...
# - Traditional ELO -- Change for A: -26.53281363354472, Change for B: 26.53281363354472
# Current A: 1777.1838301705238, Current B: 1555.8416861994106, Expected Outcome A: 0.7452134207012218, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.7452134207012218 - Change for A: -23.84682946243902, Change for B: 23.84682946243902
# Current A: 1479.9463310009107, Current B: 1490.1439160437242, Expected Outcome A: 0.4853287082096266, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.46948133729188, Change for B: -16.46948133729188
# Current A: 1496.4158123382026, Current B: 1473.6744347064323, Expected Outcome A: 0.5993876758895061, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, human_reviewer:  0.5993876758895061 - Change for A: 12.819594371535914, Change for B: -12.819594371535914
# Current A: 1579.6885156618496, Current B: 1753.3370007080848, Expected Outcome A: 0.2690198703287515, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -8.608635850520159, Change for B: 8.608635850520159
# Current A: 1571.0798798113294, Current B: 1761.945636558605, Expected Outcome A: 0.3148266120824328, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.3148266120824328 - Change for A: -10.074451586637906, Change for B: 10.074451586637906
# Current A: 1196.8842365854307, Current B: 1460.8548403348964, Expected Outcome A: 0.17952971703180481, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 26.255049054982237, Change for B: -26.255049054982237
# Current A: 1223.139285640413, Current B: 1434.5997912799141, Expected Outcome A: 0.4317627654237369, Actual Outcome A: 1
# - Logistic Regression - Reviewera: liang_etal, human_reviewer:  0.4317627654237369 - Change for A: 18.183591506440507, Change for B: -18.183591506440507
# Current A: 1416.4161997734736, Current B: 1241.3228771468534, Expected Outcome A: 0.7326125373797732, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -23.443601196152713, Change for B: 23.443601196152713
# Current A: 1392.972598577321, Current B: 1264.7664783430062, Expected Outcome A: 0.28360962720607363, Actual Outcome A: 0
# - Logistic Regression - Reviewera: human_reviewer, liang_etal:  0.28360962720607363 - Change for A: -9.075508070594424, Change for B: 9.075508070594424
# Current A: 1772.0200881452429, Current B: 1561.0054282246915, Expected Outcome A: 0.7711291548075558, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -24.676132953841716, Change for B: 24.676132953841716
# Current A: 1747.3439551914012, Current B: 1585.6815611785332, Expected Outcome A: 0.3956462196763489, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.3956462196763489 - Change for A: -12.660679029643234, Change for B: 12.660679029643234
# Current A: 1509.2354067097385, Current B: 1383.8970905067265, Expected Outcome A: 0.6729384183867645, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 10.465970611623561, Change for B: -10.465970611623561
# Current A: 1519.701377321362, Current B: 1373.431119895103, Expected Outcome A: 0.5653461664358103, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, human_reviewer:  0.5653461664358103 - Change for A: 13.90892267405411, Change for B: -13.90892267405411
# Current A: 1359.5221972210488, Current B: 1273.8419864136006, Expected Outcome A: 0.6208634971677005, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -19.86763190936631, Change for B: 19.86763190936631
# Current A: 1339.6545653116825, Current B: 1293.709618322967, Expected Outcome A: 0.8033421857475662, Actual Outcome A: 0
# - Logistic Regression - Reviewera: human_reviewer, liang_etal:  0.8033421857475662 - Change for A: -25.706949943922154, Change for B: 25.706949943922154
# Current A: 1533.6102999954162, Current B: 1319.416568266889, Expected Outcome A: 0.7743429045297036, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 7.22102705504949, Change for B: -7.22102705504949
# Current A: 1540.8313270504657, Current B: 1312.1955412118396, Expected Outcome A: 0.44349783377214397, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.44349783377214397 - Change for A: 17.808069319291462, Change for B: -17.808069319291462
# Current A: 1734.683276161758, Current B: 1598.3422402081765, Expected Outcome A: 0.6867227562499483, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -21.97512819999838, Change for B: 21.97512819999838
# Current A: 1712.7081479617596, Current B: 1620.3173684081748, Expected Outcome A: 0.6419789355695535, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.6419789355695535 - Change for A: -20.543325938225735, Change for B: 20.543325938225735
# Current A: 1558.6393963697572, Current B: 1640.8606943464006, Expected Outcome A: 0.3838345682457892, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -12.28270618386523, Change for B: 12.28270618386523
# Current A: 1546.356690185892, Current B: 1653.1434005302658, Expected Outcome A: 0.06812835423149119, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_without_knowledge:  0.06812835423149119 - Change for A: -2.1801073354076834, Change for B: 2.1801073354076834
# Current A: 1692.1648220235338, Current B: 1655.3235078656735, Expected Outcome A: 0.5528210874367196, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -17.690274797975007, Change for B: 17.690274797975007
# Current A: 1674.4745472255588, Current B: 1673.0137826636485, Expected Outcome A: 0.7452134207012218, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.7452134207012218 - Change for A: -23.84682946243902, Change for B: 23.84682946243902
# Current A: 1313.9476153677604, Current B: 1294.387471892548, Expected Outcome A: 0.5281196068274493, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -16.89982741847848, Change for B: 16.89982741847848
# Current A: 1297.0477879492819, Current B: 1311.2872993110266, Expected Outcome A: 0.3490501791644928, Actual Outcome A: 0
# - Logistic Regression - Reviewera: human_reviewer, liang_etal:  0.3490501791644928 - Change for A: -11.16960573326378, Change for B: 11.16960573326378
# Current A: 1696.8606121260875, Current B: 1650.6277177631198, Expected Outcome A: 0.5661445286875435, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -18.116624918001435, Change for B: 18.116624918001435
# Current A: 1678.743987208086, Current B: 1668.7443426811212, Expected Outcome A: 0.09325415308634671, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.09325415308634671 - Change for A: -2.984132898763164, Change for B: 2.984132898763164
# Current A: 1544.1765828504842, Current B: 1322.4569050442904, Expected Outcome A: 0.7818228891420049, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 6.9816675474558, Change for B: -6.9816675474558
# Current A: 1551.15825039794, Current B: 1315.4752374968346, Expected Outcome A: 0.5939556209290269, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.5939556209290269 - Change for A: 12.993420130271033, Change for B: -12.993420130271033
# Current A: 1302.4818173665635, Current B: 1285.878182216018, Expected Outcome A: 0.5238763782305415, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 15.235955896622727, Change for B: -15.235955896622727
# Current A: 1317.7177732631862, Current B: 1270.6422263193954, Expected Outcome A: 0.35937626903546926, Actual Outcome A: 1
# - Logistic Regression - Reviewera: liang_etal, human_reviewer:  0.35937626903546926 - Change for A: 20.499959390864888, Change for B: -20.499959390864888
# Current A: 1564.151670528211, Current B: 1338.2177326540511, Expected Outcome A: 0.7859326292683875, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -25.1498441365884, Change for B: 25.1498441365884
# Current A: 1539.0018263916227, Current B: 1363.3675767906395, Expected Outcome A: 0.4962111371028398, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.4962111371028398 - Change for A: -15.878756387290878, Change for B: 15.878756387290878
# Current A: 1675.759854309323, Current B: 1671.7284755798844, Expected Outcome A: 0.5058013600007285, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 15.814356479976595, Change for B: -15.814356479976595
# Current A: 1691.5742107892995, Current B: 1655.9141190999078, Expected Outcome A: 0.2059788974499461, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.2059788974499461 - Change for A: 25.408675281601745, Change for B: -25.408675281601745
# Current A: 1523.1230700043318, Current B: 1379.2463331779304, Expected Outcome A: 0.6959786538593457, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 9.728683076500829, Change for B: -9.728683076500829
# Current A: 1532.8517530808326, Current B: 1369.5176501014296, Expected Outcome A: 0.4550874405983699, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.4550874405983699 - Change for A: 17.437201900852187, Change for B: -17.437201900852187
# Current A: 1352.0804482005774, Current B: 1550.2889549816848, Expected Outcome A: 0.24214049881007788, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -7.748495961922572, Change for B: 7.748495961922572
# Current A: 1344.3319522386548, Current B: 1558.0374509436074, Expected Outcome A: 0.2648027846599223, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.2648027846599223 - Change for A: -8.473689109117458, Change for B: 8.473689109117458
# Current A: 1630.505443818306, Current B: 1716.9828860709013, Expected Outcome A: 0.3780568347598279, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -12.097818712314393, Change for B: 12.097818712314393
# Current A: 1618.4076251059917, Current B: 1729.0807047832157, Expected Outcome A: 0.5369443231004828, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.5369443231004828 - Change for A: -17.182218339215524, Change for B: 17.182218339215524
# Current A: 1566.5111400527248, Current B: 1335.8582631295374, Expected Outcome A: 0.7904673353914989, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 6.705045267472087, Change for B: -6.705045267472087
# Current A: 1573.216185320197, Current B: 1329.1532178620653, Expected Outcome A: 0.4962111371028398, Actual Outcome A: 1
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.4962111371028398 - Change for A: 16.121243612709122, Change for B: -16.121243612709122
# Current A: 1746.2629231224312, Current B: 1601.2254067667761, Expected Outcome A: 0.6973906563849676, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -22.31650100431898, Change for B: 22.31650100431898
# Current A: 1723.9464221181122, Current B: 1623.541907771095, Expected Outcome A: 0.1666423366517327, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.1666423366517327 - Change for A: -5.332554772855474, Change for B: 5.332554772855474
# Current A: 1628.8744625439506, Current B: 1718.6138673452567, Expected Outcome A: 0.3736519309226818, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 20.043138210474126, Change for B: -20.043138210474126
# Current A: 1648.9176007544247, Current B: 1698.5707291347826, Expected Outcome A: 0.6006859117606418, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.6006859117606418 - Change for A: 12.778050823659441, Change for B: -12.778050823659441
# Current A: 1313.0319742493562, Current B: 1589.337428932906, Expected Outcome A: 0.16930764758870784, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -5.4178447228387085, Change for B: 5.4178447228387085
# Current A: 1307.6141295265174, Current B: 1594.7552736557448, Expected Outcome A: 0.23395117568905302, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.23395117568905302 - Change for A: -7.486437622049607, Change for B: 7.486437622049607
# Current A: 1602.2417112777944, Current B: 1661.6956515780842, Expected Outcome A: 0.415264390728537, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -13.288460503313217, Change for B: 13.288460503313217
# Current A: 1588.9532507744811, Current B: 1674.9841120813974, Expected Outcome A: 0.023929023226906224, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, multi_agent_with_knowledge:  0.023929023226906224 - Change for A: -0.7657287432609792, Change for B: 0.7657287432609792
# Current A: 1675.7498408246583, Current B: 1685.7926783111232, Expected Outcome A: 0.4855512189966711, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 16.462360992106596, Change for B: -16.462360992106596
# Current A: 1692.212201816765, Current B: 1669.3303173190166, Expected Outcome A: 0.6006859117606418, Actual Outcome A: 1
# - Logistic Regression - Reviewera: multi_agent_with_knowledge, multi_agent_without_knowledge:  0.6006859117606418 - Change for A: 12.778050823659441, Change for B: -12.778050823659441
# Current A: 1656.5522664953571, Current B: 1704.9902526404244, Expected Outcome A: 0.4307402819507941, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -13.783689022425506, Change for B: 13.783689022425506
# Current A: 1642.7685774729316, Current B: 1718.77394166285, Expected Outcome A: 0.1666423366517327, Actual Outcome A: 0
# - Logistic Regression - Reviewera: multi_agent_without_knowledge, multi_agent_with_knowledge:  0.1666423366517327 - Change for A: -5.332554772855474, Change for B: 5.332554772855474
# Current A: 1300.1276919044678, Current B: 1588.1875220312202, Expected Outcome A: 0.16000301054971636, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -5.120096337590894, Change for B: 5.120096337590894
# Current A: 1295.007595566877, Current B: 1593.307618368811, Expected Outcome A: 0.1812570952606075, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.1812570952606075 - Change for A: -5.800227048339366, Change for B: 5.800227048339366
# Current A: 1289.2073685185376, Current B: 1599.1078454171504, Expected Outcome A: 0.14381846951354962, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -4.602191024433523, Change for B: 4.602191024433523
# Current A: 1284.605177494104, Current B: 1603.710036441584, Expected Outcome A: 0.23395117568905302, Actual Outcome A: 0
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.23395117568905302 - Change for A: -7.486437622049607, Change for B: 7.486437622049607
# Current A: 1611.1964740636336, Current B: 1277.1187398720544, Expected Outcome A: 0.8724843958191857, Actual Outcome A: 0
# - Traditional ELO -- Change for A: -27.919500666213935, Change for B: 27.919500666213935
# Current A: 1583.2769733974196, Current B: 1305.0382405382684, Expected Outcome A: 0.5760464678845674, Actual Outcome A: 0
# - Logistic Regression - Reviewera: barebones, liang_etal:  0.5760464678845674 - Change for A: -18.433486972306127, Change for B: 18.433486972306127
# Current A: 1323.4717275105745, Current B: 1564.8434864251135, Expected Outcome A: 0.1994959694070548, Actual Outcome A: 1
# - Traditional ELO -- Change for A: 25.616128978974302, Change for B: -25.616128978974302
# Current A: 1349.0878564895488, Current B: 1539.2273574461392, Expected Outcome A: 0.1812570952606075, Actual Outcome A: 1
# - Logistic Regression - Reviewera: liang_etal, barebones:  0.1812570952606075 - Change for A: 26.199772951660634, Change for B: -26.199772951660634
# {'barebones': 1513.0275844944786, 'multi_agent_with_knowledge': 1724.1064964357054, 'liang_etal': 1375.2876294412094, 'multi_agent_without_knowledge': 1637.4360227000761, 'human_reviewer': 1250.1422669285305}

# %%
'''
** NOT IN USE **

Testing the model for each ELO
'''

# Initialize the Elo system
elo_system = EloSystem(k_factor=32)
print("_______________________________")
print("-----Overall Quality-----------")
print("_______________________________")
# Process matches (example data, substitute with your match data)
# Assuming df is a DataFrame where you have columns 'reviewer_a', 'reviewer_b', and 'overall_quality'
for i, row in df.iterrows():
    reviewer_a = row['reviewer_a']
    reviewer_b = row['reviewer_b']
    outcome = row['overall_quality']

    elo_system.process_match(reviewer_a, reviewer_b, outcome)

# Get final ratings with confidence intervals
final_ratings_with_ci = elo_system.get_ratings_with_confidence_intervals()

# Display the results
for model, data in final_ratings_with_ci.items():
    rating = data['rating']
    lower_bound, upper_bound = data['confidence_interval']
    print(f"{model}: Rating = {rating:.2f}, 95% CI = ({lower_bound:.2f}, {upper_bound:.2f})")

print("_______________________________")
print("-----Clarity-----------")
print("_______________________________")
# Process matches (example data, substitute with your match data)
# Assuming df is a DataFrame where you have columns 'reviewer_a', 'reviewer_b', and 'overall_quality'
for i, row in df.iterrows():
    reviewer_a = row['reviewer_a']
    reviewer_b = row['reviewer_b']
    outcome = row['clarity']

    elo_system.process_match(reviewer_a, reviewer_b, outcome)

# Get final ratings with confidence intervals
final_ratings_with_ci = elo_system.get_ratings_with_confidence_intervals()

# Display the results
for model, data in final_ratings_with_ci.items():
    rating = data['rating']
    lower_bound, upper_bound = data['confidence_interval']
    print(f"{model}: Rating = {rating:.2f}, 95% CI = ({lower_bound:.2f}, {upper_bound:.2f})")
    

print("_______________________________")
print("-----Constructiveness-----------")
print("_______________________________")
# Process matches (example data, substitute with your match data)
# Assuming df is a DataFrame where you have columns 'reviewer_a', 'reviewer_b', and 'overall_quality'
for i, row in df.iterrows():
    reviewer_a = row['reviewer_a']
    reviewer_b = row['reviewer_b']
    outcome = row['constructiveness']

    elo_system.process_match(reviewer_a, reviewer_b, outcome)

# Get final ratings with confidence intervals
final_ratings_with_ci = elo_system.get_ratings_with_confidence_intervals()

# Display the results
for model, data in final_ratings_with_ci.items():
    rating = data['rating']
    lower_bound, upper_bound = data['confidence_interval']
    print(f"{model}: Rating = {rating:.2f}, 95% CI = ({lower_bound:.2f}, {upper_bound:.2f})")
    
print("_______________________________")
print("-----Technical Quality-----------")
print("_______________________________")
# Process matches (example data, substitute with your match data)
# Assuming df is a DataFrame where you have columns 'reviewer_a', 'reviewer_b', and 'overall_quality'
for i, row in df.iterrows():
    reviewer_a = row['reviewer_a']
    reviewer_b = row['reviewer_b']
    outcome = row['technical_quality']

    elo_system.process_match(reviewer_a, reviewer_b, outcome)

# Get final ratings with confidence intervals
final_ratings_with_ci = elo_system.get_ratings_with_confidence_intervals()

# Display the results
for model, data in final_ratings_with_ci.items():
    rating = data['rating']
    lower_bound, upper_bound = data['confidence_interval']
    print(f"{model}: Rating = {rating:.2f}, 95% CI = ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# _______________________________
# -----Overall Quality-----------
# _______________________________
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 17
#      14     reviewer_b = row['reviewer_b']
#      15     outcome = row['overall_quality']
# ---> 17     elo_system.process_match(reviewer_a, reviewer_b, outcome)
#      19 # Get final ratings with confidence intervals
#      20 final_ratings_with_ci = elo_system.get_ratings_with_confidence_intervals()
#
# TypeError: EloSystem.process_match() missing 2 required positional arguments: 'review_a' and 'review_b'

# %%
def calculate_win_prob(a, b):
    return 1 / (1 + 10 ** ((b - a) / 400))

mammorx = 1676.55
human = 1322.88

win_prob = calculate_win_prob(mammorx, human)

print(f"Probability of winning: {win_prob * 100:.2f}%")
# Out:
# Probability of winning: 88.45%
